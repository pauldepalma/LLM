# %%
class Animal:
   def speak(self):
       print("some sound")

# %%
class Dog(Animal):
    def speak(self):
        print("Woof")

# %%
d = Dog()
d.speak()
# Out:
# Woof

# %%
# Out:
# (tensor([0.]),)
# (tensor([-0.2497]),)
