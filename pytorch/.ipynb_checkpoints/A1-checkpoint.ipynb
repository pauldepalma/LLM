# %%
import torch
# Out:
# /Users/depalma/Desktop/LLM/.venv/lib/python3.11/site-packages/torch/_subclasses/functional_tensor.py:258: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
import sys
print(sys.executable)
# Out:
# /Users/depalma/Desktop/LLM/.venv/bin/python

# %%
# !{sys.executable} -m pip show torch
# Out:
# Name: torch
# Version: 2.4.0
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /Users/depalma/Desktop/LLM/.venv/lib/python3.11/site-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, typing-extensions
# Required-by:

# %%
import torch
print(torch.__version__)
# Out:
# 2.4.0

# %%
import torch

# %%
tensor0d = torch.tensor(1)

# %%
tensor1d = torch.tensor([1,2,3])

# %%
tensor2d = torch.tensor([[1,2],
                        [3,4]])

# %%
tensor3d = torch.tensor([[[1,2],[3,4]],
                        [[5,6],  [7,8]]])

# %%
tensor3d.shape
# Out:
# torch.Size([2, 2, 2])
